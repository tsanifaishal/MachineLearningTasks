# %% [markdown]
# <a href="https://colab.research.google.com/github/tsanifaishal/MachineLearningTasks/blob/main/5thWeekTasks/Task5_EDA_IT_Salary_M_Tsani_Faishal_Azhar_1103210143.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : M Tsani Faishal Azhar
# NIM : 1103210143
# Judul : Tugas lecture 5 model IDE dari dataset IT Salary

# %% [markdown]
# Prompt : Beri kode untuk menghubungkan google drive ke google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Prompt : Beri kode untuk read dataset as dataframe dengan path "/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv"

# %%
import pandas as pd

# Ganti path dengan path yang sesuai di perangkat Anda
path = "/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv"

# Membaca dataset sebagai dataframe
df = pd.read_csv(path)

# Menampilkan beberapa baris pertama dari dataframe
print(df.head())
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# Prompt : Beri kode untuk menampilkan informasi ringkas dari dataframe

# %%
# Menampilkan informasi ringkas tentang dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %% [markdown]
# Prompt : Beri petunjuk untuk melakukan Exploratory Data Analysis

# %% [markdown]
# Berikut ini panduan langkah demi langkah untuk melakukan Exploratory Data Analysis (EDA):
#
# 1. Memahami Data: Mulailah dengan memahami struktur data Anda. Identifikasi jumlah kolom, nama kolom, dan jenis data yang ada. Pastikan Anda memahami apa yang mewakili setiap kolom.
#
# 2. Pemeriksaan Data Awal: Periksa data Anda untuk mengidentifikasi nilai yang hilang, nilai yang tidak valid, atau potensi outliers. Lakukan pembersihan data awal jika diperlukan, seperti mengisi nilai yang hilang atau menghapus baris atau kolom yang tidak relevan.
#
# 3. Statistik Deskriptif: Hitung statistik deskriptif untuk setiap variabel numerik dalam dataset Anda, seperti mean, median, standar deviasi, nilai minimum, dan nilai maksimum. Ini memberi Anda gambaran awal tentang distribusi data.
#
# 4. Visualisasi Data: Gunakan berbagai jenis visualisasi seperti histogram, box plot, scatter plot, dan heatmap untuk memahami distribusi data, korelasi antar variabel, dan pola-pola lainnya dalam data Anda. Visualisasi membantu Anda dengan cepat mengidentifikasi tren, anomali, atau pola yang menarik.
#
# 5. Analisis Univariate: Analisis setiap variabel secara terpisah. Lihat distribusi variabel numerik dan frekuensi variabel kategorikal. Hal ini membantu Anda memahami karakteristik masing-masing variabel dengan lebih baik.
#
# 6. Analisis Bivariate: Analisis hubungan antara dua variabel. Identifikasi korelasi antara variabel numerik dan hubungan antara variabel numerik dan kategorikal. Gunakan teknik visualisasi seperti scatter plot atau box plot untuk menganalisis hubungan ini.
#
# 7. Analisis Multivariate: Analisis yang melibatkan tiga atau lebih variabel sekaligus. Anda dapat menggunakan teknik seperti heatmap untuk menganalisis korelasi antar semua variabel dalam dataset.
#
# 8. Analisis Pembanding: Bandingkan subset data atau kelompok data berbeda untuk mengidentifikasi perbedaan signifikan antara mereka. Anda dapat menggunakan teknik visualisasi seperti bar plot atau box plot untuk analisis ini.
#
# 9. Analisis Anomali: Identifikasi dan analisis nilai-nilai yang tidak biasa atau outlier dalam data Anda. Pertimbangkan apakah outlier tersebut merupakan data yang valid atau apakah mereka perlu diperlakukan secara khusus.
#
# 10. Interpretasi dan Kesimpulan: Setelah menganalisis data Anda, buatlah kesimpulan tentang temuan Anda. Jelaskan apa yang Anda pelajari dari analisis Anda dan bagaimana hal itu dapat menginformasikan keputusan atau langkah selanjutnya.
#
# 11. Dokumentasi: Jangan lupa untuk mendokumentasikan langkah-langkah yang Anda ambil dan hasil analisis Anda. Ini penting untuk berbagi temuan Anda dengan orang lain dan memungkinkan replikasi analisis Anda di masa depan.

# %% [markdown]
# Prompt : Beri kode untuk mendapatkan summary statistical dari dataframe

# %%
# Mendapatkan summary statistik dari dataframe
summary_stats = df.describe()

# Menampilkan summary statistik
print(summary_stats)
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %% [markdown]
# Prompt : Beri kode untuk melihat 5 baris teratas dari fitur-fitur tertentu beikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", "Сontract duration", "Company size"

# %%
# Melihat lima baris teratas dari fitur-fitur tertentu
selected_features = ["Total years of experience", "Years of experience in Germany",
                     "Yearly bonus + stocks in EUR",
                     "Annual bonus+stocks one year ago. Only answer if staying in same country",
                     "Number of vacation days", "Сontract duration", "Company size"]

print(df[selected_features].head())
# Out:
#   Total years of experience Years of experience in Germany  \
# 0                         5                              3
# 1                         7                              4
# 2                        12                              6
# 3                         4                              1
# 4                        17                              6
#
#   Yearly bonus + stocks in EUR  \
# 0                         5000
# 1                          NaN
# 2                       120000
# 3                          NaN
# 4                          NaN
#
#   Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days   Сontract duration Company size
# ...

# %% [markdown]
# Prompt : Beri kode untuk mengubah fitur-fitur tertentu berikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", "Сontract duration", "Company size", bertipe data numerik

# %%
# Fitur-fitur yang akan diubah menjadi tipe data numerik
selected_features = ["Total years of experience", "Years of experience in Germany",
                     "Yearly bonus + stocks in EUR",
                     "Annual bonus+stocks one year ago. Only answer if staying in same country",
                     "Number of vacation days", "Сontract duration", "Company size"]

# Mengubah fitur-fitur menjadi tipe data numerik
df[selected_features] = df[selected_features].apply(pd.to_numeric, errors='coerce')

# Memeriksa tipe data setelah perubahan
print(df[selected_features].dtypes)
# Out:
# Total years of experience                                                   float64
# Years of experience in Germany                                              float64
# Yearly bonus + stocks in EUR                                                float64
# Annual bonus+stocks one year ago. Only answer if staying in same country    float64
# Number of vacation days                                                     float64
# Сontract duration                                                           float64
# Company size                                                                float64
# dtype: object

# %% [markdown]
# Prompt : Beri kode untuk menampilkan baris yang memiliki null value

# %%
# Menemukan baris yang memiliki nilai null
rows_with_null = df[df.isnull().any(axis=1)]

# Menampilkan baris yang memiliki nilai null
print(rows_with_null)
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position   Total years of experience  \
# 0                          Software Engineer                        5.0
# 1                          Backend Developer                        7.0
# 2                          Software Engineer                       12.0
# ...

# %% [markdown]
# Prompt : Beri kode untuk mengisi baris dari feature "Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week" yang memiliki null value dengan nilai "0"

# %%
# Mengisi nilai null dengan "0" untuk fitur "Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week"
df["Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week"].fillna(0, inplace=True)

# Menampilkan beberapa baris pertama dari dataframe setelah pengisian nilai null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
import matplotlib.pyplot as plt

# Membuat rentang umur dengan jarak 10 tahun
bins = [20, 30, 40, 50, 60, 70]
labels = ['20-29', '30-39', '40-49', '50-59', '60-69']


# Menambahkan kolom baru 'Age Range' dengan rentang umur yang sesuai
df['Age Range'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Menghitung jumlah observasi untuk setiap rentang umur
age_range_counts = df['Age Range'].value_counts()

# Plotting diagram pie
plt.figure(figsize=(8, 8))
plt.pie(age_range_counts, labels=age_range_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Rentang Umur')
plt.axis('equal')  # Membuat lingkaran menjadi bentuk lingkaran
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan baris data yang memiliki Age 60+

# %%
# Memilih baris data dengan usia 60+
age_60_plus = df[df['Age'] >= 60]

# Menampilkan baris data yang memiliki usia 60+
print(age_60_plus)
# Out:
#                 Timestamp   Age Gender       City          Position   \
# 59    24/11/2020 11:33:51  66.0   Male     Munich  Software Engineer
# 296   24/11/2020 15:39:13  65.0   Male     Berlin  Software Engineer
# 1103  06/12/2020 21:51:21  69.0   Male  Stuttgart            Rentner
#
#       Total years of experience  Years of experience in Germany  \
# 59                         40.0                             4.0
# 296                        25.0                            25.0
# 1103                      383.0                             3.0
#
#      Seniority level Your main technology / programming language  \
# 59              Lead                               ruby on rails
# 296           Senior                          Pascal, VB.NET, C#
# 1103            Head                                         NaN
#
#      Other technologies/programming languages you use often  ...  \
# 59                   Javascript / Typescript, Ruby, SQL      ...
# ...

# %% [markdown]
# Prompt : Beri kode untuk membandingkan Total fitur Total experience dengan Age dalam rentang umur yang tadi

# %%
# Membuat rentang umur dengan jarak 10 tahun
bins = [20, 30, 40, 50, 60, 70]
labels = ['20-29', '30-39', '40-49', '50-59', '60-69']

# Menambahkan kolom baru 'Age Range' dengan rentang umur yang sesuai
df['Age Range'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Plotting scatter plot untuk membandingkan Total years of experience dengan Age dalam rentang umur yang telah ditentukan
plt.figure(figsize=(10, 6))
for age_range in labels:
    plt.scatter(df[df['Age Range'] == age_range]['Total years of experience'], df[df['Age Range'] == age_range]['Age'], label=age_range)

plt.xlabel('Total years of experience')
plt.ylabel('Age')
plt.title('Perbandingan Total years of experience dan Age dalam Rentang Umur')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Prompt : Beri kode untuk membandingkan Total fitur "Yearly brutto salary (without bonus and stocks) in EUR" dengan Age dalam rentang umur yang tadi, visualisasikan dengan stick diagram

# %%
# Membuat rentang umur dengan jarak 10 tahun
bins = [20, 30, 40, 50, 60, 70]
labels = ['20-29', '30-39', '40-49', '50-59', '60-69']

# Menambahkan kolom baru 'Age Range' dengan rentang umur yang sesuai
df['Age Range'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Menghitung rata-rata gaji tahunan brutto (tanpa bonus dan saham) untuk setiap rentang umur
average_salary_by_age = df.groupby('Age Range')['Yearly brutto salary (without bonus and stocks) in EUR'].mean()

# Plotting stick diagram untuk membandingkan rata-rata gaji tahunan brutto dengan rentang umur
plt.figure(figsize=(10, 6))
plt.stem(average_salary_by_age.index.astype(str), average_salary_by_age, markerfmt=' ', linefmt='b-')
plt.xlabel('Age Range')
plt.ylabel('Average Yearly brutto salary (without bonus and stocks) in EUR')
plt.title('Perbandingan Rata-rata Yearly brutto salary (without bonus and stocks) dengan Rentang Umur')
plt.grid(True, axis='y')
plt.show()
